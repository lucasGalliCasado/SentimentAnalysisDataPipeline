# %% [markdown]
# Google News Scrapper con Analisis de sentimiento

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.common.action_chains import ActionChains
import openai
from openai import OpenAI
from newspaper import Article
from newspaper.article import ArticleException

# %%
client = OpenAI(api_key="tuclaveOpenAI")

# Maxima cantidad de dias desde la publicacion del articulo hasta el dia de la fecha 
cantDias = 25

#Base de datos de articulos
df = pd.DataFrame(columns=["Query", "Titulo","Fecha","Url","Texto","Sentimiento"])


#Categorias de busquedo y las queries asociadas a la misma
queries = {
    "Politica": ["Milei","Caputo"],
    "Economia": ["Comercio","Finanzas","Pyme"],
    "Actual": ["RIGI"]
    }


'''
Diccionario para url's de articulos segun su categoria. Respeta del orden de busqueda, i.e. el primer articulo 
scrapeado para coyuntura sera el primer url de la clave Coyuntura
'''
articulos_links = {key: [] for key in queries}

articulos_titulo = {key: [] for key in queries}


def extract_article_data(url):
    try:
        articloTemp = Article(url)
        articloTemp.download()
        articloTemp.parse()
        
        titulo = articloTemp.title
        fecha = articloTemp.publish_date.strftime("%d-%m-%Y") if articloTemp.publish_date else None
        texto = articloTemp.text
        fuente = articloTemp.source_url if articloTemp.publish_date else None

        return titulo, fecha, texto, fuente
    except ArticleException:
        return None, None, None, None


def process_article(driver, article_xpath,query):
    #Buscamos el articulo por xpath por hasta 10seg
    try:
        article_title = WebDriverWait(driver, 10).until(
            EC.presence_of_element_located((By.XPATH, article_xpath))
        )
        #Guardamos el Url del articulo
        #NOTA: Este es un url que se redirige a el url de verddad
        url_sin_redirigir = article_title.get_attribute("href")

        #Vamos a la pagina a lo que nos redirige google news y guardamos el url final
        driver.get(url_sin_redirigir)
        time.sleep(1)
        url_final = driver.current_url

        #Retornamos al driver a la pagina con el query actual
        driver.get(url_google_news)

        #Guardamos el url del articulo en bajo su respectiva clave
        articulos_links[key].append(url_final)

        #Usando Newspaper3k extraemos la info del articulo
        #OBS; A veces falla la fecha, el titulo y el texto suelen extraerse bien
        titulo, fecha, texto, fuente = extract_article_data(url_final)

        articulos_titulo[key].append(titulo)

        #Con el fin de almacen la fuente sin caracteres de mas removemos algunas palabras innecesarias
        if fuente is not None:
            fuente = fuente.replace('https://', '')
            fuente = fuente.replace('www.', '')
            fuente = fuente.replace('.com', '')
            fuente = fuente.replace('.ar', '')
            fuente = fuente.replace('.net', '')
            fuente = fuente.replace('.org', '')

        if texto is not None and texto != "":

            #resumen = resumenArticulo(texto)
            completion = client.chat.completions.create(
                    #Aca estamos usando el modelo mas barato, sale $0.001 USD y tenes $5 USD menseuales gratuitos
                    model="gpt-3.5-turbo",
                    messages=[
                    {"role": "user", "content": f"Te voy a pasar un texto, haz un analisis de sentimiento y responde simplemente con 'positivo' ,'negativo' o 'nuetral'. Aca esta el texto : {texto}"}])
            
            sentimiento = completion.choices[0].message.content.lower()



            #Fila que sera añadida a la base de datos 
            fila_articulo = {"Query":query,  "Titulo":titulo,"Fecha":fecha, "Url":url_final,"Texto":texto , "Sentimiento": sentimiento}

            df.loc[len(df)] = fila_articulo

        else:
            print("Error con la extracción del artículo.")
    
    #Excepciones    
    except TimeoutException:
        print(f"No se encontró artículo en la ruta {article_xpath}.")
    
    except Exception as e:
        print(f"Error al procesar artículo: {e}")


for key in queries:

    print(f"Inicio de temas de {key}\n")
    
    for q in queries[key]:
        print(f"Inicio de sub-busqueda de {q}\n")
        
        url_google_news = f"https://news.google.com/search?q=%22{q}%22%20when%3A{cantDias}d&hl=es-419&gl=AR&ceid=AR%3Aes-419"
        
        with webdriver.Chrome() as driver:
            driver.get(url_google_news)
            time.sleep(8)

            #identificadores de los articulos a tomar, por default se toman los primeros 7
            xpaths = [
                '//*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[1]/c-wiz/article/div[1]/div[1]/a',
                '//*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[2]/c-wiz/article/div[1]/div[1]/a',
                '//*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[3]/c-wiz/article/div[1]/div[1]/a',
                '//*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[4]/c-wiz/article/div[1]/div[1]/a',
                '//*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[5]/c-wiz/article/div[1]/div[1]/a',
                '//*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[6]/c-wiz/article/div[1]/div[1]/a',
                '//*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[7]/c-wiz/article/div[1]/div[1]/a'
            ]

            for xpath in xpaths:
                process_article(driver, xpath,q)
        
        print(f"Fin de sub-busqueda de {q}\n")
    print(f"Fin de busqueda de {key}\n")
# Out:
# Inicio de temas de Politica
#
# Inicio de sub-busqueda de Milei
#
# Fin de sub-busqueda de Milei
#
# Inicio de sub-busqueda de Caputo
#
# Fin de sub-busqueda de Caputo
#
# Fin de busqueda de Politica
#
# Inicio de temas de Economia
#
# Inicio de sub-busqueda de Comercio
#
# Fin de sub-busqueda de Comercio
#
# Inicio de sub-busqueda de Finanzas
#
# Fin de sub-busqueda de Finanzas
#
# Inicio de sub-busqueda de Pyme
#
# Fin de sub-busqueda de Pyme
#
# Fin de busqueda de Economia
#
# Inicio de temas de Actual
#
# Inicio de sub-busqueda de RIGI
#
# No se encontró artículo en la ruta //*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[4]/c-wiz/article/div[1]/div[1]/a.
# No se encontró artículo en la ruta //*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[5]/c-wiz/article/div[1]/div[1]/a.
# No se encontró artículo en la ruta //*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[6]/c-wiz/article/div[1]/div[1]/a.
# No se encontró artículo en la ruta //*[@id="yDmH0d"]/c-wiz/div/main/div[2]/c-wiz/c-wiz[7]/c-wiz/article/div[1]/div[1]/a.
# Fin de sub-busqueda de RIGI
#
# Fin de busqueda de Actual

# %%
#Pasamos nuestros query's de un formato de url a uno coloquial
for index, row in df.iterrows():
    df.at[index, 'Query'] = row['Query'].replace('%20', ' ')

current_time = time.localtime()

# Format the time into a string with the format "day_month"
dia_mes = time.strftime("%d_%m", current_time)

# Especificar el nombre del archivo de Excel
nombre_archivo = f"baseDeDatos__noticias{dia_mes}.xlsx"

# Guardar el DataFrame en un archivo de Excel
df.to_excel(nombre_archivo, index=False)

print(f"El DataFrame se ha guardado en el archivo {nombre_archivo}")
# Out:
# El DataFrame se ha guardado en el archivo baseDeDatos__noticias05_08.xlsx

# %%
df
# Out:
#        Query                                             Titulo       Fecha  \
# 0      Milei  Javier Milei, en vivo: las últimas medidas del...  05-08-2024
# 1      Milei  “En la Argentina del Presidente Milei las empr...  30-07-2024
# 2      Milei  Los viajes de Javier Milei al exterior, uno po...  13-07-2024
# 3      Milei  Kicillof: “La única realidad es que Milei deci...         NaN
# 4      Milei  Milei tiene que dar las gracias a Kicillof | E...         NaN
# 5      Milei  Milei desautoriza a su vicepresidenta, Victori...  19-07-2024
# 6      Milei  Cruzan a Milei por vincular a la izquierda con...  15-07-2024
# 7     Caputo  Luis Caputo se reunió con Agentes de Liquidaci...  30-07-2024
# 8     Caputo  Sáenz y Caputo avanzaron en un acuerdo para qu...         NaN
# 9     Caputo  El plan Caputo de "secar la plaza (y los bolsi...         NaN
# 10    Caputo  “Mejor custodiado afuera”: Caputo confirmó el ...  19-07-2024
# 11    Caputo  Santiago Caputo: “Macri sentó las bases para q...  01-08-2024
# 12    Caputo  El mercado le creyó a Luis Caputo y se dispara...  31-07-2024
# 13    Caputo  Giro de oro al exterior: qué se sabe sobre la ...  20-07-2024
# 14  Comercio  El Gobierno Nacional desburocratiza el comerci...  04-08-2024
# 15  Comercio  Cuánto gana un empleado de comercio en julio 2024  23-07-2024
# 16  Comercio  Mendoza intensifica la lucha contra el comerci...         NaN
# 17  Comercio  Comercio exterior: se aplicaron nuevas normas ...  19-07-2024
# 18  Comercio  Emprendedores salteños hacia la economía digit...         NaN
# 19  Finanzas  Trabaja en finanzas y da la fórmula para no “e...  02-08-2024
# 20  Finanzas  Moratoria que fortalecerá las finanzas del Hos...  01-08-2024
# 21  Finanzas                    Enderezar las finanzas públicas  17-07-2024
# 22  Finanzas  Milei y Caputo, reflejo de la soberbia de las ...         NaN
# 23  Finanzas  Horóscopo y dinero: cómo le irá a los signos e...  02-08-2024
# 24  Finanzas  Experto en finanzas: “Argentina es uno de los ...         NaN
# 25  Finanzas  Carlos Burgueño: "El Messi de las finanzas est...  15-07-2024
# 26      Pyme  Buenos Aires Ciudad - Gobierno de la Ciudad Au...         NaN
# 27      Pyme         Premios Pyme 2024: Conocé a los finalistas  29-07-2024
# 28      Pyme  La recesión no para: la industria pyme cayó 20...  21-07-2024
# 29      Pyme  Competencia difícil: una pyme de Córdoba le da...  29-07-2024
# 30      Pyme  “Todo suma para tu Pyme, gatín”, revelan chats...         NaN
# 31      Pyme        La industria pyme cay� 20,4% anual en junio         NaN
# 32      Pyme  Ley Nacional PyME: “Con esta ley se podría rea...  16-07-2024
# 33      RIGI  “Es mentira que el cambio de la planta de GNL ...         NaN
# 34      RIGI  Kicillof cruzó a Milei por la planta de GNL: "...         NaN
# 35      RIGI  RIGI: perspectivas y blindaje para las grandes...  20-07-2024
#
#                                                   Url  \
# 0   https://www.lanacion.com.ar/politica/javier-mi...
# 1   https://www.argentina.gob.ar/noticias/en-la-ar...
# 2   https://chequeado.com/el-explicador/uno-por-un...
# 3   https://www.gba.gob.ar/comunicacion_publica/ga...
# 4   https://www.pagina12.com.ar/757570-milei-tiene...
# 5   https://elpais.com/argentina/2024-07-19/milei-...
# 6   https://www.clacso.org/cruzan-a-milei-por-vinc...
# 7   https://www.argentina.gob.ar/noticias/luis-cap...
# 8   https://www.salta.gob.ar/prensa/noticias/saenz...
# 9   https://www.pagina12.com.ar/757653-el-plan-cap...
# 10  https://www.lanacion.com.ar/economia/mejor-cus...
# 11  https://www.infobae.com/politica/2024/08/01/sa...
# 12  https://www.clarin.com/economia/mercado-creyo-...
# 13  https://chequeado.com/el-explicador/giro-de-or...
# 14  https://www.argentina.gob.ar/noticias/el-gobie...
# 15  https://www.lanacion.com.ar/economia/cuanto-ga...
# 16  https://www.mendoza.gov.ar/prensa/mendoza-inte...
# 17  https://www.infobae.com/movant/2024/07/19/come...
# 18  https://www.salta.gob.ar/prensa/noticias/empre...
# 19  https://www.lanacion.com.ar/salud/descanso/tra...
# 20  http://www.rauch.mun.gba.gov.ar/web/index.php/...
# 21  https://elpais.com/opinion/2024-07-17/endereza...
# 22  https://www.pagina12.com.ar/752975-milei-y-cap...
# 23  https://www.clarin.com/astrologia/horoscopo-di...
# 24  https://www.lavoz.com.ar/negocios/experto-en-f...
# 25  https://www.perfil.com/noticias/modo-fontevecc...
# 26  https://buenosaires.gob.ar/desarrolloeconomico...
# 27  https://www.clarin.com/brandstudio/premios-pym...
# 28  https://www.infobae.com/economia/2024/07/21/la...
# 29  https://www.lanacion.com.ar/economia/campo/com...
# 30  https://www.lavoz.com.ar/politica/todo-suma-pa...
# 31  https://www.redcame.org.ar/prensa/13794/la-ind...
# 32  https://www.perfil.com/noticias/canal-e/ley-na...
# 33  https://www.pagina12.com.ar/756713-es-mentira-...
# 34  https://www.lapoliticaonline.com/politica/kici...
# 35  https://www.infobae.com/opinion/2024/07/20/rig...
#
#                                                 Texto Sentimiento
# 0   Escuchar\n\n📌08.18 | La reacción de Sturzenegg...    positivo
# 1   \n\n\n\nEl Vocero Presidencial Manuel Adorni a...     neutral
# 2   Estados Unidos fue el destino más frecuente, c...     neutral
# 3   “Estamos ante un hecho de enorme gravedad, una...    negativo
# 4   Sin la presentación pública de un informe técn...    negativo
# 5   La defensa que hizo la vicepresidenta Victoria...    negativo
# 6   Compartimos una nota publicada en Página 12 el...    positivo
# 7   El ministro de Economía, Luis Caputo, mantuvo ...     neutral
# 8   El gobernador de Salta Gustavo Sáenz y el mini...    positivo
# 9   El impacto de la recesión sigue sintiéndose co...    negativo
# 10  Escuchar\n\nEl ministro de Economía, Luis Capu...     neutral
# 11  El principal asesor presidencial Santiago Capu...    positivo
# 12  Los bonos subieron más de 4% este miércoles, d...    positivo
# 13  El diputado nacional y líder del Sindicato de ...    positivo
# 14  Con el objetivo de continuar con el proceso de...    positivo
# 15  Escuchar\n\nLos empleados de comercio reciben ...     neutral
# 16  En nuevos operativos, la Policía secuestró más...    positivo
# 17  Entre las normativas, se encuentra la moderniz...    positivo
# 18  De esta manera se formará y capacitará a los e...    positivo
# 19  Escuchar\n\nDicen que todas las buenas histori...    positivo
# 20  Está vigente desde hoy, 1 de agosto, la Ordena...    positivo
# 21  El Gobierno anunció este martes las grandes ci...    positivo
# 22  El gobierno hace uso y abuso del lenguaje macr...    negativo
# 23  Este mes de agosto es un mes “movido”: aún se ...     neutral
# 24  “El mercado es como un barquito de remo. De un...    positivo
# 25  El politólogo, Carlos Burgueño, contó que no s...     neutral
# 26  La iniciativa busca mejorar las problemáticas ...    positivo
# 27  Brand Studio para Premios PYME\n\nLa séptima e...    positivo
# 28  El depósito de una pyme industrial, con mercad...    negativo
# 29  Escuchar\n\nCÓRDOBA.- En el noroeste cordobés ...     neutral
# 30  Un peritaje sobre los teléfonos celulares de M...    negativo
# 31  La actividad manufacturera de las pymes dismin...    negativo
# 32  Luego de las constantes quejas por parte del s...     neutral
# 33  El gobernador de la provincia de Buenos Aires,...     neutral
# 34  Axel Kicillof cuestionó duramente la decisión ...    negativo
# 35  El régimen declara a las grandes inversiones c...    positivo
